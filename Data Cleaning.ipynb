# %%
import numpy as np 
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
path = "C:\\Users\\USER\\Desktop\\MY PROJECT\\loan prediction using machine learning\\"
train = pd.read_csv(path + "train.csv")
test = pd.read_csv(path + "test.csv")

# %%
train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
train.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
test.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
test.sample(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 18   LP001108    Male     Yes          0      Graduate            No
# 254  LP002397  Female     Yes          1      Graduate            No
# 344  LP002876    Male      No          0      Graduate            No
# 187  LP002056    Male     Yes          2      Graduate            No
# 37   LP001210    Male     Yes          0      Graduate           Yes
# 294  LP002610    Male     Yes          1  Not Graduate           NaN
# 227  LP002270    Male     Yes          1      Graduate            No
# 105  LP001561  Female     Yes          0      Graduate            No
# 15   LP001099    Male      No          1      Graduate            No
# 71   LP001368    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 18              9226               7916       300.0             360.0
# ...

# %%
train.sample(8)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 613  LP002990  Female      No          0      Graduate           Yes
# 185  LP001640    Male     Yes          0      Graduate           Yes
# 514  LP002652    Male      No          0      Graduate            No
# 231  LP001768    Male     Yes          0      Graduate           NaN
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 169  LP001580    Male     Yes          2      Graduate            No
# 60   LP001205    Male     Yes          0      Graduate            No
# 342  LP002119    Male     Yes          1  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 613             4583                0.0       133.0             360.0
# 185            39147             4750.0       120.0             360.0
# 514             5815             3666.0       311.0             360.0
# ...

# %%
test.info()
# from the describtion below, it has 367 rows and 12 columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
train.shape
# Out:
# (614, 13)

# %%
train.shape[1]
# Out:
# 13

# %%
train.shape[0]
# Out:
# 614

# %% [raw]
# test.isna().sum()

# %%
test.shape
# Out:
# (367, 12)

# %%
test.shape[0]
# Out:
# 367

# %%
test.shape[1]
# Out:
# 12

# %%
misssing_values= train.isna().sum()

# %%
cent_misssing_values= round((train.isna().sum()/train.shape[0])*100,2)
cent_misssing_values
# Out:
# Loan_ID              0.00
# Gender               2.12
# Married              0.49
# Dependents           2.44
# Education            0.00
# Self_Employed        5.21
# ApplicantIncome      0.00
# CoapplicantIncome    0.00
# LoanAmount           3.58
# Loan_Amount_Term     2.28
# Credit_History       8.14
# Property_Area        0.00
# Loan_Status          0.00
# dtype: float64

# %%
join= pd.concat([misssing_values,cent_misssing_values], axis=1, keys= ["misssing_values","cent_misssing_values"])
join
# Out:
#                    misssing_values  cent_misssing_values
# Loan_ID                          0                  0.00
# Gender                          13                  2.12
# Married                          3                  0.49
# Dependents                      15                  2.44
# Education                        0                  0.00
# Self_Employed                   32                  5.21
# ApplicantIncome                  0                  0.00
# CoapplicantIncome                0                  0.00
# LoanAmount                      22                  3.58
# Loan_Amount_Term                14                  2.28
# Credit_History                  50                  8.14
# Property_Area                    0                  0.00
# Loan_Status                      0                  0.00

# %%
join=join[join["cent_misssing_values"]>0]
join
# Out:
#                   misssing_values  cent_misssing_values
# Gender                         13                  2.12
# Married                         3                  0.49
# Dependents                     15                  2.44
# Self_Employed                  32                  5.21
# LoanAmount                     22                  3.58
# Loan_Amount_Term               14                  2.28
# Credit_History                 50                  8.14

# %%
missing_values=test.isnull().sum()
missing_values
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
cent_misssing_values= round((test.isnull().sum()/test.shape[0])*100,2)
cent_misssing_values
# Out:
# Loan_ID              0.00
# Gender               3.00
# Married              0.00
# Dependents           2.72
# Education            0.00
# Self_Employed        6.27
# ApplicantIncome      0.00
# CoapplicantIncome    0.00
# LoanAmount           1.36
# Loan_Amount_Term     1.63
# Credit_History       7.90
# Property_Area        0.00
# dtype: float64

# %%
joined=pd.concat([missing_values,cent_misssing_values], axis=1, keys= ["missing_values","cent_missing_values"])
joined
# Out:
#                    missing_values  cent_missing_values
# Loan_ID                         0                 0.00
# Gender                         11                 3.00
# Married                         0                 0.00
# Dependents                     10                 2.72
# Education                       0                 0.00
# Self_Employed                  23                 6.27
# ApplicantIncome                 0                 0.00
# CoapplicantIncome               0                 0.00
# LoanAmount                      5                 1.36
# Loan_Amount_Term                6                 1.63
# Credit_History                 29                 7.90
# Property_Area                   0                 0.00

# %%
joined= joined[joined["missing_values"]>0]
joined
# Out:
#                   missing_values  cent_missing_values
# Gender                        11                 3.00
# Dependents                    10                 2.72
# Self_Employed                 23                 6.27
# LoanAmount                     5                 1.36
# Loan_Amount_Term               6                 1.63
# Credit_History                29                 7.90

# %%
x=pd.concat([join, joined], axis=1, keys=["join","joined"])
x
# Out:
#                             join                              joined  \
#                  misssing_values cent_misssing_values missing_values
# Gender                        13                 2.12           11.0
# Married                        3                 0.49            NaN
# Dependents                    15                 2.44           10.0
# Self_Employed                 32                 5.21           23.0
# LoanAmount                    22                 3.58            5.0
# Loan_Amount_Term              14                 2.28            6.0
# Credit_History                50                 8.14           29.0
#
#
#                  cent_missing_values
# Gender                          3.00
# Married                          NaN
# Dependents                      2.72
# Self_Employed                   6.27
# LoanAmount                      1.36
# Loan_Amount_Term                1.63
# Credit_History                  7.90
